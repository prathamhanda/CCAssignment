# %% [markdown]
# <a href="https://colab.research.google.com/github/prathamhanda/PyAssignment/blob/main/Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Name: Pratham Handa <br>
# Roll No: 102317106 <br>
# Sub-Group: 2Q14 <br>
# Assignment 1 Submission

# %%
# 1.2
def print_name():
    name = "Pratham"
    print(name * 3)

# 2.1
def add_three_numbers():
    a = 10
    b = 20
    c = 30
    print(a + b + c)

# 2.2
def concat_three_strings():
    a = "Hello "
    b = "World "
    c = "Python"
    print(a + b + c)

# 4.1
def table_of_n(n):
    for i in range(1, 11):
        print(n * i)

# 4,2
def add_all_numbers(n):
    total = 0
    for i in range(1, n+1):
        total += i
    print(total)

# 4.3
def max_amoung_three_numbers(a, b, c):
    print(max(a, b, c))

# 5.1
def add_divisible_by_7_and_9(n):
    total = 0
    for i in range(1, n+1):
        if i % 7 == 0 and i % 9 == 0:
            total += i
    print(total)

# 5.2
def is_prime(n):
    if n < 2:
        return False
    for i in range(2, n):
        if n % i == 0:
            return False
    return True

# 5.3
def add_prime_numbers(n):
    total = 0
    for i in range(1, n+1):
        if is_prime(i):
            total += i
    print(total)

# 6.1
def add_odd_numbers(n):
    total = 0
    for i in range(1, n+1):
        if i % 2 != 0:
            total += i
    print(total)

# 6.2
def add_prime_numbers(n):
    total = 0
    for i in range(1, n+1):
        if is_prime(i):
            total += i
    print(total)


print("Answer : ")
print_name()
print("Answer : ")
add_three_numbers()
print("Answer : ")
concat_three_strings()
print("Answer : ")
table_of_n(7)
print("Answer : ")
table_of_n(9)
print("Answer : ")
add_all_numbers(10)
print("Answer : ")
max_amoung_three_numbers(10, 20, 30)
print("Answer : ")
add_divisible_by_7_and_9(100)
print("Answer : ")
add_prime_numbers(100)
print("Answer : ")
add_odd_numbers(100)
print("Answer : ")
add_prime_numbers(100)
# Out:
# Answer :
# PrathamPrathamPratham
# Answer :
# 60
# Answer :
# Hello World Python
# Answer :
# 7
# 14
# 21
# 28
# 35
# 42
# 49
# 56
# 63
# 70
# Answer :
# 9
# 18
# 27
# 36
# 45
# 54
# 63
# 72
# 81
# 90
# Answer :
# 55
# Answer :
# 30
# Answer :
# 63
# Answer :
# 1060
# Answer :
# 2500
# Answer :
# 1060
